# %% [markdown]
# # Lab 3 · Accountability & Human Oversight
#
# The policy says who is accountable and what a human approves. This notebook
# produces the evidence you need to write that policy for a system that
# actually exists.
#
# The Console from Lab 0, then five reports. Every number is produced by
# running the agent, not by reading its documentation.
#
# **Run every cell. Screenshot Steps 3, 4, 5, 6 and 7.**

# %% [markdown]
# ## Step 1: Install
#
# **Runtime > Run all**, or run this cell on its own. About a minute.
#
# If your network blocks `git`, this falls back to a direct download on its own.

# %%
#@title Step 1: Install { display-mode: "form" }
import io, os, shutil, subprocess, sys, urllib.request, zipfile

DIR  = "agentic-gov-labs"
REPO = "https://github.com/francoisarthanas/agentic-gov-labs.git"
ZIP  = ("https://github.com/francoisarthanas/agentic-gov-labs"
        "/archive/refs/heads/main.zip")

if os.path.isdir(DIR) and not os.path.isdir(os.path.join(DIR, "supportflow")):
    shutil.rmtree(DIR)                      # half-finished download

if not os.path.isdir(DIR):
    r = subprocess.run(["git", "clone", "--depth", "1", REPO, DIR],
                       capture_output=True, text=True)
    if r.returncode != 0:
        print("git clone did not work here, downloading the zip instead.")
        try:
            with urllib.request.urlopen(ZIP, timeout=60) as resp:
                z = zipfile.ZipFile(io.BytesIO(resp.read()))
            z.extractall(".")
            shutil.move("agentic-gov-labs-main", DIR)
        except Exception as e:
            print("Could not download the labs:", e)
            print("Check your connection and run this cell again.")

if DIR not in sys.path:
    sys.path.insert(0, DIR)

try:
    import supportflow as sf
    print(f"SupportFlow v{sf.__version__} ready. Move to Step 2.")
except ImportError as e:
    print("Not loaded yet:", e)
    print("Run this cell once more. It recovers on its own most times.")

# %% [markdown]
# ## Step 2: Open the Console
#
# Same Console as Lab 0. Run this cell, then click the **public URL** ending in `.gradio.live` to open it in its own tab.
#
# Keep it open. The reports below print numbers; the Console is where you go to see the run behind any number for yourself. You will need the **Trace** tab for the approval packet in Step 7.

# %%
#@title Step 2: Launch the Console { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run Step 1 above, then come back to this cell.")

if sf:
    sf.launch()

# %% [markdown]
# ## Step 3: Does the code enforce the SOP?
#
# The **Refund SOP, section 7** lists the things that must go to a human.
#
# This cell tests every one of them by putting the words in a customer's mouth
# and watching what the agent does.
#
# **Screenshot the output.**

# %%
#@title Step 3: Test every escalation trigger { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.accountability.triggers()

# %% [markdown]
# ## Step 4: How much reaches a human, and what holds when nothing does?
#
# The first table runs all six scenarios twice: once with the human approval
# gate on, once with it off.
#
# The second table asks a question the architecture notes could not answer.
# Marcus Hale wrote that he did not know whether the refund ceiling was
# **enforced in the tool wrapper** or **only stated in the agent instructions**.
#
# **Read the Gate OFF column carefully before you draw a conclusion.**
#
# **Screenshot both tables.**

# %%
#@title Step 4: Oversight sweep, then wall or sign { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.accountability.sweep()
    print()
    sf.accountability.wall_or_sign()

# %% [markdown]
# ## Step 5: The accountability evidence report
#
# Your policy contains a RACI matrix. Every row of it names somebody
# **Accountable** for an activity.
#
# This cell goes through those activities one at a time and asks a single
# question of the running system:
#
# > **What evidence is there that anybody did this?**
#
# **Screenshot the output. This is what you take back to the policy.**

# %%
#@title Step 5: Accountability evidence report { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.accountability.raci()

# %% [markdown]
# ## Step 6: The request on your desk
#
# Support Ops has asked to raise the refund ceiling from **$200 to $500** and
# move the agent up one autonomy level before the holiday peak.
#
# This cell runs every scenario under today's settings and under the requested
# ones, and counts what still reaches a person.
#
# **Screenshot the output.**

# %%
#@title Step 6: What the request changes { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.accountability.dana()

# %% [markdown]
# ## Step 7: The approval packet
#
# When SupportFlow escalates, a human is asked to approve a payment. This cell
# shows exactly what that human receives, next to everything the system already
# knew at the moment it wrote the request.
#
# You will redesign this packet in VerifyWise. **Everything you need is in the
# second table.** To see it live, open the Console, run **S2**, and read the **Trace** tab.
#
# **Screenshot the output.**

# %%
#@title Step 7: What the approver receives { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.accountability.packet()

# %% [markdown]
# ---
#
# **What to do with this**
#
# Go to **Governance > Policy manager** in VerifyWise and create a policy from
# template 1, **AI Accountability and Roles Policy**. Its RACI matrix is where
# your answers go. Your Step 5 report says what evidence exists for each row.
# Your Step 7 report is the raw material for the approval packet you will
# write into it.
#
# ---
#
# * Do not commit employer, client or customer data to your fork
# * Every customer, order and address in this system is fictional
