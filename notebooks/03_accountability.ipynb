# %% [markdown]
# # This notebook has moved
#
# Lab 6 · Design & Validate Human Oversight now lives at **`06_oversight.ipynb`**.
#
# Open it here: https://colab.research.google.com/github/francoisarthanas/agentic-gov-labs/blob/main/notebooks/06_oversight.ipynb
#
# Nothing else changed. Same steps, same Console, same reports.
