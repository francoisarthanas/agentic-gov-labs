# %% [markdown]
# # Lab 7 · Threat-Model the Agent & Design Security Controls
#
# Follow the Lab 7 instructions in Maven. **Runtime > Run all**, then read the five outputs.
#
# Each one takes a step from the attack you just read and asks it of SupportFlow.

# %% [markdown]
# ## Step 1: Install

# %%
#@title Step 1: Install { display-mode: "form" }
import io, os, shutil, subprocess, sys, urllib.request, zipfile

DIR  = "agentic-gov-labs"
REPO = "https://github.com/francoisarthanas/agentic-gov-labs.git"
ZIP  = ("https://github.com/francoisarthanas/agentic-gov-labs"
        "/archive/refs/heads/main.zip")


def _clone():
    r = subprocess.run(["git", "clone", "--depth", "1", REPO, DIR],
                       capture_output=True, text=True)
    if r.returncode != 0:
        print("git clone did not work here, downloading the zip instead.")
        with urllib.request.urlopen(ZIP, timeout=60) as resp:
            z = zipfile.ZipFile(io.BytesIO(resp.read()))
        z.extractall(".")
        shutil.move("agentic-gov-labs-main", DIR)


# A runtime you have used before may already hold an older copy of the labs.
# Bring it up to date, and start over if it will not come.
if os.path.isdir(DIR):
    fresh = False
    if os.path.isdir(os.path.join(DIR, ".git")):
        r = subprocess.run(["git", "-C", DIR, "pull", "--ff-only", "-q"],
                           capture_output=True, text=True)
        fresh = r.returncode == 0
    if not fresh or not os.path.isdir(os.path.join(DIR, "supportflow")):
        shutil.rmtree(DIR, ignore_errors=True)

if not os.path.isdir(DIR):
    try:
        _clone()
    except Exception as e:
        print("Could not download the labs:", e)
        print("Check your connection and run this cell again.")

if DIR not in sys.path:
    sys.path.insert(0, DIR)

for _m in [m for m in list(sys.modules) if m.split(".")[0] == "supportflow"]:
    del sys.modules[_m]                     # never import a half-old package

try:
    import supportflow as sf
    print(f"SupportFlow v{sf.__version__} ready. Move to Step 2.")
except ImportError as e:
    print("Not loaded yet:", e)
    print("Run this cell once more. It recovers on its own most times.")

# %% [markdown]
# ## Row 1: They emailed the address the agent watches, and got a reply
#
# Can a message from outside reach this agent, and does it reply?

# %%
#@title Row 1 { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.threatmodel.step1()

# %% [markdown]
# ## Row 2: They got the agent to reveal its own tools and data sources
#
# Does this system treat its own configuration as anything worth protecting?

# %%
#@title Row 2 { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.threatmodel.step2()

# %% [markdown]
# ## Row 3: They made it return an entire knowledge base file
#
# What can the agent read, and who can write to it?

# %%
#@title Row 3 { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.threatmodel.step3()

# %% [markdown]
# ## Row 4: They made it return the customer records
#
# **Read this one slowly.** One lookup, and everything that comes back.

# %%
#@title Row 4 { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.threatmodel.step4()

# %% [markdown]
# ## Row 5: They made it email everything to an outside address
#
# Who decides where the agent's email goes?

# %%
#@title Row 5 { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.threatmodel.step5()

# %% [markdown]
# ## The control panel
#
# Every control in the system, and which ones are on. You need this for sentence 2.

# %%
#@title The control panel { display-mode: "form" }
import os, sys
DIR = "agentic-gov-labs"
if os.path.exists(DIR) and DIR not in sys.path:
    sys.path.insert(0, DIR)
try:
    import supportflow as sf
except ImportError:
    sf = None
    print("SupportFlow is not loaded yet.")
    print("Run the Step 1 cell at the top of this notebook, then try again.")

if sf:
    sf.threatmodel.panel()

# %% [markdown]
# ---
#
# Every customer, order and address in this system is fictional. Do not put employer, client or customer data into your copy of this notebook.
